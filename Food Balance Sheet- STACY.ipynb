# %%
# importing Libraries
import pandas as pd

# %%
# mporting the data set
food_balance_sheet = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')
food_balance_sheet.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food_balance_sheet.shape
# Out:
# (60943, 12)

# %%
food_balance_sheet.describe(include = 'all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
food_balance_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
food_balance_sheet.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
Area_2014 = food_balance_sheet.groupby('Area')['Y2014'].sum()
sort_2014 = Area_2014.sort_values(ascending = False)
sort_2014
# Out:
# Area
# Nigeria                        1399542.19
# Egypt                           849192.30
# South Africa                    497289.52
# Ethiopia                        415935.50
# Morocco                         375977.76
# United Republic of Tanzania     337430.64
# Algeria                         313375.33
# Ghana                           308328.59
# Kenya                           255211.01
# Sudan                           247577.56
# Uganda                          218142.33
# Cameroon                        217630.28
# Angola                          208584.42
# Côte d'Ivoire                   195982.84
# Malawi                          173454.86
# Mozambique                      160757.87
# Madagascar                      128985.32
# Mali                            123038.75
# Benin                           118050.79
# Tunisia                         117029.33
# Mauritania                      109557.63
# Niger                           108236.65
# ...

# %%
Area_2018 = food_balance_sheet.groupby('Area')['Y2018'].sum()
sort_2018 = Area_2018.sort_values(ascending = False)
sort_2018
# Out:
# Area
# Nigeria                        1499774.24
# Egypt                           852652.92
# South Africa                    509787.97
# Ethiopia                        450788.86
# Morocco                         399271.27
# Ghana                           358915.64
# United Republic of Tanzania     349763.41
# Algeria                         341729.98
# Kenya                           270916.80
# Sudan                           268054.39
# Angola                          235206.68
# Cameroon                        233022.93
# Côte d'Ivoire                   227018.00
# Uganda                          222147.25
# Malawi                          187366.09
# Mozambique                      164934.05
# Mali                            159026.42
# Mauritania                      157479.95
# Madagascar                      134576.44
# Niger                           133982.86
# Tunisia                         127343.17
# Benin                           124960.70
# ...

# %%
Area_2017 = food_balance_sheet.groupby('Area')['Y2017'].sum()
sort_2017 = Area_2018.sort_values(ascending = False)
sort_2017
# Out:
# Area
# Nigeria                        1499774.24
# Egypt                           852652.92
# South Africa                    509787.97
# Ethiopia                        450788.86
# Morocco                         399271.27
# Ghana                           358915.64
# United Republic of Tanzania     349763.41
# Algeria                         341729.98
# Kenya                           270916.80
# Sudan                           268054.39
# Angola                          235206.68
# Cameroon                        233022.93
# Côte d'Ivoire                   227018.00
# Uganda                          222147.25
# Malawi                          187366.09
# Mozambique                      164934.05
# Mali                            159026.42
# Mauritania                      157479.95
# Madagascar                      134576.44
# Niger                           133982.86
# Tunisia                         127343.17
# Benin                           124960.70
# ...

# %%
Area_2017 = food_balance_sheet.groupby('Element')['Y2017'].sum()
sort_2017 = Area_2018.sort_values(ascending = False)
sort_2017
# Out:
# Area
# Nigeria                        1499774.24
# Egypt                           852652.92
# South Africa                    509787.97
# Ethiopia                        450788.86
# Morocco                         399271.27
# Ghana                           358915.64
# United Republic of Tanzania     349763.41
# Algeria                         341729.98
# Kenya                           270916.80
# Sudan                           268054.39
# Angola                          235206.68
# Cameroon                        233022.93
# Côte d'Ivoire                   227018.00
# Uganda                          222147.25
# Malawi                          187366.09
# Mozambique                      164934.05
# Mali                            159026.42
# Mauritania                      157479.95
# Madagascar                      134576.44
# Niger                           133982.86
# Tunisia                         127343.17
# Benin                           124960.70
# ...
